# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikoo7/Machine_Learning-BDA-/blob/main/Casestudy123.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("early_wakeup_health_dataset.csv")
df.shape
# Out:
# (10000, 64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 64 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Person_ID                       10000 non-null  object
#  1   Age                             10000 non-null  int64
#  2   Gender                          10000 non-null  object
#  3   Height_cm                       10000 non-null  float64
#  4   Weight_kg                       10000 non-null  float64
#  5   BMI                             10000 non-null  float64
#  6   Country                         10000 non-null  object
#  7   Occupation                      10000 non-null  object
#  8   Marital_Status                  10000 non-null  object
#  9   Wake_Up_Time                    10000 non-null  object
#  10  Sleep_Time                      10000 non-null  object
#  11  Sleep_Duration_Hours            10000 non-null  float64
# ...

# %% [markdown]
# # Drop Columns
#
# ( irrelevent & possible target)

# %%
df.drop(columns=['Obesity_Risk'	,
'Hypertension_Risk'	,
'Diabetes_Risk'	,
'Cardiovascular_Risk'	,
'Sleep_Disorder_Risk'	,
'Health_Score'	,
'Healthy_Aging_Score'	,
'Wellness_Category'	,
'Early_Waker',
'Depression_Risk_Score',
'Gym_Member',
'Height_cm',
'Weight_kg',
'Person_ID',],inplace=True)
df.shape
# Out:
# (10000, 50)

# %% [markdown]
# # Convert date time to category

# %%
df['Wake_Up_Time'] = pd.to_datetime( df['Wake_Up_Time'])
df['Sleep_Time'] = pd.to_datetime( df['Sleep_Time'])
# Out:
# /tmp/ipykernel_3289/2732240999.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Wake_Up_Time'] = pd.to_datetime( df['Wake_Up_Time'])
# /tmp/ipykernel_3289/2732240999.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Sleep_Time'] = pd.to_datetime( df['Sleep_Time'])

# %%
sorted(df['Sleep_Time'].unique())
# Out:
# [Timestamp('2026-06-28 00:00:00'),
#  Timestamp('2026-06-28 00:01:00'),
#  Timestamp('2026-06-28 00:02:00'),
#  Timestamp('2026-06-28 00:03:00'),
#  Timestamp('2026-06-28 00:04:00'),
#  Timestamp('2026-06-28 00:05:00'),
#  Timestamp('2026-06-28 00:06:00'),
#  Timestamp('2026-06-28 00:07:00'),
#  Timestamp('2026-06-28 00:08:00'),
#  Timestamp('2026-06-28 00:09:00'),
#  Timestamp('2026-06-28 00:10:00'),
#  Timestamp('2026-06-28 00:11:00'),
#  Timestamp('2026-06-28 00:12:00'),
#  Timestamp('2026-06-28 00:13:00'),
#  Timestamp('2026-06-28 00:14:00'),
#  Timestamp('2026-06-28 00:15:00'),
#  Timestamp('2026-06-28 00:16:00'),
#  Timestamp('2026-06-28 00:17:00'),
#  Timestamp('2026-06-28 00:18:00'),
#  Timestamp('2026-06-28 00:19:00'),
#  Timestamp('2026-06-28 00:20:00'),
#  Timestamp('2026-06-28 00:21:00'),
#  Timestamp('2026-06-28 00:22:00'),
#  Timestamp('2026-06-28 00:23:00'),
#  Timestamp('2026-06-28 00:24:00'),
#  Timestamp('2026-06-28 00:25:00'),
#  Timestamp('2026-06-28 00:26:00'),
# ...

# %%
df['WT_cat'] = 0

# %%
df.loc[(df['Wake_Up_Time'] >= "2026-06-27 04:00:00") &
       (df['Wake_Up_Time'] < "2026-06-27 06:00:00"), "WT_cat"]=0
df.loc[(df['Wake_Up_Time'] >= "2026-06-27 06:00:00") &
       (df['Wake_Up_Time'] < "2026-06-27 08:00:00"), "WT_cat"]=1
df.loc[(df['Wake_Up_Time'] >= "2026-06-27 08:00:00") &
       (df['Wake_Up_Time'] < "2026-06-27 10:00:00"), "WT_cat"]=2
df.loc[(df['Wake_Up_Time'] >= "2026-06-27 10:00:00") &
       (df['Wake_Up_Time'] <= "2026-06-27 11:00:00"), "WT_cat"]=3

# %%
df['WT_cat'].unique()
# Out:
# array([0])

# %%
df['ST_cat'] = 0

# %%
df.loc[(df['Sleep_Time'] >= "2026-06-27 20:00:00") &
       (df['Sleep_Time'] < "2026-06-27 22:00:00"), "ST_cat"]=0
df.loc[(df['Sleep_Time'] >= "2026-06-27 22:00:00") &
       (df['Sleep_Time'] <= "2026-06-27 23:59:00"), "ST_cat"]=1
df.loc[(df['Sleep_Time'] >= "2026-06-27 00:00:00") &
       (df['Sleep_Time'] < "2026-06-27 03:00:00"), "ST_cat"]=2
df.loc[(df['Sleep_Time'] >= "2026-06-27 03:00:00") &
       (df['Sleep_Time'] < "2026-06-27 07:00:00"), "ST_cat"]=3
df.loc[(df['Sleep_Time'] >= "2026-06-27 18:00:00") &
       (df['Sleep_Time'] < "2026-06-27 20:00:00"), "ST_cat"]=4

# %%
df['ST_cat'].unique()
# Out:
# array([0])

# %%
df.drop(columns=['Wake_Up_Time',
                 'Sleep_Time'],inplace=True)

# %%
df.shape
# Out:
# (10000, 50)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'Country', 'Occupation', 'Marital_Status',
#        'Sleep_Duration_Hours', 'Sleep_Quality_Score',
#        'Number_of_Night_Awakenings', 'Weekend_Sleep_Difference_Hours',
#        'Nap_Frequency_Per_Week', 'Screen_Time_Before_Bed_Hours',
#        'Exercise_Frequency_Per_Week', 'Exercise_Duration_Minutes',
#        'Exercise_Type', 'Daily_Steps', 'Morning_Workout', 'Workout_Intensity',
#        'Daily_Calorie_Intake', 'Water_Intake_Liters', 'Fruit_Intake_Per_Day',
#        'Vegetable_Intake_Per_Day', 'Protein_Intake_Grams',
#        'Sugary_Drinks_Per_Week', 'Fast_Food_Meals_Per_Week',
#        'Breakfast_Regularity_Score', 'Smoking_Status', 'Alcohol_Consumption',
#        'Stress_Level', 'Working_Hours_Per_Day', 'Sitting_Hours_Per_Day',
#        'Outdoor_Time_Hours', 'Social_Interaction_Score', 'Meditation_Practice',
#        'Resting_Heart_Rate', 'Systolic_BP', 'Diastolic_BP',
#        'Cholesterol_Level', 'Blood_Sugar_Level', 'Energy_Level_Score',
# ...

# %% [markdown]
# # Fill missing values

# %%
df.isnull().sum()#
# Out:
# Age                                  0
# Gender                               0
# BMI                                  0
# Country                              0
# Occupation                           0
# Marital_Status                       0
# Sleep_Duration_Hours                 0
# Sleep_Quality_Score                  0
# Number_of_Night_Awakenings           0
# Weekend_Sleep_Difference_Hours       0
# Nap_Frequency_Per_Week               0
# Screen_Time_Before_Bed_Hours         0
# Exercise_Frequency_Per_Week          0
# Exercise_Duration_Minutes            0
# Exercise_Type                      824
# Daily_Steps                          0
# Morning_Workout                      0
# Workout_Intensity                  824
# Daily_Calorie_Intake                 0
# Water_Intake_Liters                  0
# Fruit_Intake_Per_Day                 0
# Vegetable_Intake_Per_Day             0
# Protein_Intake_Grams                 0
# Sugary_Drinks_Per_Week               0
# ...

# %%
df.loc[df['Alcohol_Consumption'].isna() == True,
       'Alcohol_Consumption'] = 0

# %%
df[['Exercise_Type','Workout_Intensity']].mode().iloc[0]
# Out:
# Exercise_Type        Weight Training
# Workout_Intensity           Moderate
# Name: 0, dtype: object

# %%
fill_value = df.mode().iloc[0]
df.fillna(fill_value,inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Handle ordinal columns
#
# label encoding

# %%
df['Workout_Intensity'].unique()
# Out:
# array(['Low', 'Moderate', 'High'], dtype=object)

# %%
df['Smoking_Status'].unique()
# Out:
# array(['Former', 'Current', 'Never'], dtype=object)

# %%
df['Alcohol_Consumption'].unique()
# Out:
# array(['Moderate', 0, 'Light', 'Heavy'], dtype=object)

# %%
label_map={'Workout_Intensity':{'Low':0, 'Moderate':1, 'High':2},
  'Smoking_Status':{'Former':1, 'Current':2, 'Never':0},
  'Alcohol_Consumption':{'Moderate':2, 'Light':1, 'Heavy':3}
}

# %%
df.replace(label_map,inplace=True)
# Out:
# /tmp/ipykernel_3289/1715271054.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(label_map,inplace=True)

# %%
df['Alcohol_Consumption'].unique()
# Out:
# array([2, 0, 1, 3])

# %%
df['Smoking_Status'].unique()
# Out:
# array([1, 2, 0])

# %%
df['Workout_Intensity'].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# # Check

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             10000 non-null  int64
#  1   Gender                          10000 non-null  object
#  2   BMI                             10000 non-null  float64
#  3   Country                         10000 non-null  object
#  4   Occupation                      10000 non-null  object
#  5   Marital_Status                  10000 non-null  object
#  6   Sleep_Duration_Hours            10000 non-null  float64
#  7   Sleep_Quality_Score             10000 non-null  float64
#  8   Number_of_Night_Awakenings      10000 non-null  int64
#  9   Weekend_Sleep_Difference_Hours  10000 non-null  float64
#  10  Nap_Frequency_Per_Week          10000 non-null  int64
#  11  Screen_Time_Before_Bed_Hours    10000 non-null  float64
# ...

# %% [markdown]
# # X & Y split
#
# target : fitness level

# %%
X = df.drop(columns=['Fitness_Level'])
Y = df['Fitness_Level']
X.shape,Y.shape
# Out:
# ((10000, 49), (10000,))

# %%
Y.unique()
# Out:
# array(['Excellent', 'Good', 'Average', 'Poor'], dtype=object)

# %%
label_map = {'Excellent':3, 'Good':2, 'Average':1, 'Poor':0}
Y.replace(label_map,inplace=True)
# Out:
# /tmp/ipykernel_3289/1394058508.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Y.replace(label_map,inplace=True)

# %%
Y.unique()
# Out:
# array([3, 2, 1, 0])

# %%
X_ohe = pd.get_dummies(X)
X_ohe.shape
# Out:
# (10000, 91)

# %%
X_ohe.columns
# Out:
# Index(['Age', 'BMI', 'Sleep_Duration_Hours', 'Sleep_Quality_Score',
#        'Number_of_Night_Awakenings', 'Weekend_Sleep_Difference_Hours',
#        'Nap_Frequency_Per_Week', 'Screen_Time_Before_Bed_Hours',
#        'Exercise_Frequency_Per_Week', 'Exercise_Duration_Minutes',
#        'Daily_Steps', 'Workout_Intensity', 'Daily_Calorie_Intake',
#        'Water_Intake_Liters', 'Fruit_Intake_Per_Day',
#        'Vegetable_Intake_Per_Day', 'Protein_Intake_Grams',
#        'Sugary_Drinks_Per_Week', 'Fast_Food_Meals_Per_Week',
#        'Breakfast_Regularity_Score', 'Smoking_Status', 'Alcohol_Consumption',
#        'Stress_Level', 'Working_Hours_Per_Day', 'Sitting_Hours_Per_Day',
#        'Outdoor_Time_Hours', 'Social_Interaction_Score', 'Resting_Heart_Rate',
#        'Systolic_BP', 'Diastolic_BP', 'Cholesterol_Level', 'Blood_Sugar_Level',
#        'Energy_Level_Score', 'Fatigue_Level_Score', 'Immune_Health_Score',
#        'Mood_Score', 'Anxiety_Score', 'Productivity_Score',
# ...

# %%
cat_col = X_ohe.columns[X_ohe.nunique() <= 15]
cat_col.shape
# Out:
# (61,)

# %%
cont_col = X_ohe.columns[X_ohe.nunique() > 15]
cont_col.shape
# Out:
# (30,)

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X_ohe,Y,
                                                 test_size=0.3,
                                                 random_state=7,
                                                 stratify=Y)
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((7000, 91), (3000, 91), (7000,), (3000,))

# %%
from sklearn.preprocessing import RobustScaler
rc= RobustScaler()
X_train[cont_col] = rc.fit_transform(X_train[cont_col])
X_test[cont_col] = rc.transform(X_test[cont_col])

# %% [markdown]
# # Outlier imputation using IQR method

# %%
def outlier_imputation_iqr(df,col):
  df1 = df.copy()
  q1,q3 = df1[col].quantile([0.25,0.75])
  iqr = q3-q1
  LB = q1 - 1.5*iqr
  UB = q3 + 1.5*iqr
  print("Column -->",col)
  df1.loc[(df1[col]<LB),col] = LB
  df1.loc[(df1[col]>UB),col] = UB
  print(LB,UB, df1[col].min(),df1[col].max())
  return df1

# %%
X_train_io = X_train.copy()
for col in cont_col:
  X_train_io = outlier_imputation_iqr(X_train_io,col)
# Out:
# Column --> Age
# -1.9642857142857144 2.0357142857142856 -0.8928571428571429 1.3214285714285714
# Column --> BMI
# -2.0089153046062407 1.9910846953937595 -1.4257057949479945 1.9910846953937595
# Column --> Sleep_Duration_Hours
# -2.0033557046979866 1.9966442953020134 -2.0033557046979866 1.8523489932885902
# Column --> Sleep_Quality_Score
# -2.0 2.0 -2.0 1.7272727272727282
# Column --> Weekend_Sleep_Difference_Hours
# -2.0092592592592595 1.9907407407407407 -1.8888888888888888 1.9907407407407407
# Column --> Screen_Time_Before_Bed_Hours
# -1.8664122137404582 2.133587786259542 -0.618320610687023 2.133587786259542
# Column --> Exercise_Duration_Minutes
# -2.0 2.0 -1.6071428571428572 2.0
# Column --> Daily_Steps
# -2.025921583952065 1.9740784160479354 -1.9954409274456169 1.9740784160479354
# Column --> Daily_Calorie_Intake
# -1.9973230220107079 2.0026769779892923 -1.9973230220107079 2.0026769779892923
# Column --> Water_Intake_Liters
# ...

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=0.95,random_state=7)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)
X_train_pca.shape, X_test_pca.shape
# Out:
# ((7000, 43), (3000, 43))

# %%
pca = PCA(n_components=0.95,random_state=7)
X_train_io_pca = pca.fit_transform(X_train_io)
X_test_io_pca = pca.transform(X_test)
X_train_io_pca.shape, X_test_io_pca.shape
# Out:
# ((7000, 43), (3000, 43))

# %% [markdown]
# ## KERNEL PCA

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(kernel='rbf',random_state=7)
X_train_kpca = kpca.fit_transform(X_train)
X_test_kpca = kpca.transform(X_test)
X_train_kpca.shape, X_test_kpca.shape
# Out:
# ((7000, 6999), (3000, 6999))

# %%
kpca = KernelPCA(kernel='rbf',random_state=7)
X_train_io_kpca = kpca.fit_transform(X_train_io)
X_test_io_kpca = kpca.transform(X_test)
X_train_io_kpca.shape, X_test_io_kpca.shape
# Out:
# ((7000, 6999), (3000, 6999))

# %% [markdown]
# ## RFE

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
rfe = RFE(LogisticRegression(random_state=7,
                             class_weight="balanced"),
          verbose=2)
rfe.fit(X_train,Y_train)
rfe.ranking_
# Out:
# Fitting estimator with 91 features.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting estimator with 90 features.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
selected_col = X_train.columns[rfe.ranking_ == 1]
selected_col.shape
# Out:
# (45,)

# %%
X_train_rfe = X_train.loc[:,selected_col]
X_test_rfe = X_test.loc[:,selected_col]

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
rfe = RFE(LogisticRegression(random_state=7,
                             class_weight="balanced"),
          verbose=2)
rfe.fit(X_train_io,Y_train)
rfe.ranking_
# Out:
# Fitting estimator with 91 features.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting estimator with 90 features.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
selected_col = X_train_io.columns[rfe.ranking_ == 1]
selected_col.shape
# Out:
# (45,)

# %%
X_train_io_rfe = X_train_io.loc[:,selected_col]
X_test_io_rfe = X_test.loc[:,selected_col]

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(class_weight="balanced",
                            random_state=7)
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=7)

# %%
selected_col = X_train.columns[dt.feature_importances_ >
                               dt.feature_importances_.mean()]
selected_col.shape
# Out:
# (20,)

# %%
X_train_dt = X_train.loc[:,selected_col]
X_test_dt = X_test.loc[:,selected_col]

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(class_weight="balanced",
                            random_state=7)
dt.fit(X_train_io,Y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=7)

# %%
selected_col = X_train_io.columns[dt.feature_importances_ >
                               dt.feature_importances_.mean()]
selected_col.shape
# Out:
# (21,)

# %%
X_train_io_dt = X_train_io.loc[:,selected_col]
X_test_io_dt = X_test.loc[:,selected_col]

# %% [markdown]
# # Apply Models for Multi - Class Classification

# %% [markdown]
#  --> TO get the best model for your data and get the best prediction =
#  models to select:
# atleast 3
# 1) basic learning -- Like Logistic
# --> Random Forest
# 1 out of XGBoost, CatBoost, Or LGBoost
#
# best performing of the three is selected

# %% [markdown]
# # Apply models for multi class classification
#
# Logistic Regression
#
# ---
#
# CatBoost
#
# ---
#
# RandomForest
#
# ---
#
# LightGBM
#
# --
# apply on all datasets -- generate 40 different classification report fo each

# %% [markdown]
# # # Steps to be done:
# 1. take the model
# 2. train the model
# 3. get the predictions Y_predict and Y_pred_prob
# 4. Classification Report
# 5. log loss

# %% [markdown]
# # automation:
# create a function that will take model,Xtrain,Ytrain,Ytest as a parameter and in turn return precision,recall,f1score log loss, average precision score.
#
# run this function on diff datasets and models and store the list of lists
#
# convert it to a dataframe
#
# compare the results in the dataframe
#
# PLot the results if possible!

# %%
data_list = [(X_train,X_test),(X_train_io,X_test),(X_train_pca,X_test_pca),(X_train_io_pca,X_test_io_pca),(X_train_kpca,X_test_kpca),
             (X_train_io_kpca,X_test_io_kpca),(X_train_rfe,X_test_rfe),(X_train_io_rfe,X_test_io_rfe),(X_train_dt,X_test_dt),(X_train_io_dt,X_test_io_dt)]
# All required training datasets for different feature selections

# %%
from sklearn.metrics import classification_report
c = 0
for XTrain,XTest in data_list:
  c += 1
  lr = LogisticRegression(random_state=7,class_weight='balanced')
  lr.fit(XTrain,Y_train)
  y_pred = lr.predict(XTest)
  print(f'Classification Report : {c} - {classification_report(Y_test,y_pred)}')
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Classification Report : 1 -               precision    recall  f1-score   support
#
#            0       0.54      0.79      0.64        34
#            1       0.80      0.83      0.81       641
#            2       0.84      0.79      0.81      1329
#            3       0.85      0.88      0.86       996
#
#     accuracy                           0.83      3000
#    macro avg       0.76      0.82      0.78      3000
# ...

# %% [markdown]
# For Random Forest Classifier

# %%
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
c = 0
for XTrain,XTest in data_list:
  c += 1
  rf = RandomForestClassifier(class_weight='balanced',random_state=7,n_estimators=100)
  rf.fit(XTrain,Y_train)
  y_pred = rf.predict(XTest)
  print(f'Classification Report : {c} - {classification_report(Y_test,y_pred)}')
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
# !pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 6.7 MB/s eta 0:00:00
# ...

# %%
from catboost import CatBoostClassifier

# %%
c = 0
for XTrain,XTest in data_list:
  c += 1
  cbc = CatBoostClassifier(iterations=50,learning_rate=0.5,depth=5,cat_features=None,loss_function='MultiClass',random_state=7)
  cbc.fit(XTrain,Y_train)
  y_pred = cbc.predict(XTest)
  print(f'Classification Report : {c} - {classification_report(Y_test,y_pred)}')
# Out:
# 0:	learn: 1.0051672	total: 81.4ms	remaining: 3.99s
# 1:	learn: 0.8253709	total: 109ms	remaining: 2.61s
# 2:	learn: 0.7218339	total: 140ms	remaining: 2.19s
# 3:	learn: 0.6667324	total: 167ms	remaining: 1.93s
# 4:	learn: 0.6197175	total: 196ms	remaining: 1.76s
# 5:	learn: 0.5881995	total: 218ms	remaining: 1.6s
# 6:	learn: 0.5586230	total: 238ms	remaining: 1.46s
# 7:	learn: 0.5357815	total: 258ms	remaining: 1.35s
# 8:	learn: 0.5179448	total: 278ms	remaining: 1.26s
# 9:	learn: 0.5006852	total: 307ms	remaining: 1.23s
# 10:	learn: 0.4856634	total: 336ms	remaining: 1.19s
# 11:	learn: 0.4711568	total: 361ms	remaining: 1.14s
# 12:	learn: 0.4612380	total: 387ms	remaining: 1.1s
# 13:	learn: 0.4497093	total: 411ms	remaining: 1.06s
# 14:	learn: 0.4447636	total: 437ms	remaining: 1.02s
# 15:	learn: 0.4391059	total: 460ms	remaining: 978ms
# 16:	learn: 0.4286773	total: 484ms	remaining: 939ms
# 17:	learn: 0.4202179	total: 505ms	remaining: 898ms
# 18:	learn: 0.4161895	total: 531ms	remaining: 866ms
# ...

# %%
import lightgbm as lgb

# %%
c = 0
for XTrain,XTest in data_list:
  c += 1
  lgbm = lgb.LGBMClassifier(learning_rate=0.5,n_estimators=50,subsample=0.8,colsample_bytree=0.8,max_depth=5,random_state=7)
  lgbm.fit(XTrain,Y_train)
  y_pred = lgbm.predict(XTest)
  print(f'Classification Report : {c} - {classification_report(Y_test,y_pred)}')
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004457 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4491
# [LightGBM] [Info] Number of data points in the train set: 7000, number of used features: 89
# [LightGBM] [Info] Start training from score -4.471639
# [LightGBM] [Info] Start training from score -1.543115
# [LightGBM] [Info] Start training from score -0.814508
# [LightGBM] [Info] Start training from score -1.102620
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# Write automation code i.e fn --> takes model,X_train,X_test,Y_train,Y_test as parameters and automate further
